# %% [markdown]
# <a href="https://colab.research.google.com/github/ldmrepo/study-nural-net/blob/main/linear_regression01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: torch를 사용하여 선형회기 샘플코드생성

import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim

# Create a synthetic data set
x = torch.linspace(-1, 1, 100)
x = x.view(-1, 1)
y = x.pow(2) + 0.2 * torch.rand(x.size())

# Define the linear regression model
class LinearRegression(nn.Module):
  def __init__(self):
    super(LinearRegression, self).__init__()
    self.linear = nn.Linear(1, 1)

  def forward(self, x):
    return self.linear(x)

# Instantiate the model
model = LinearRegression()

# Define the loss function and optimizer
loss_fn = nn.MSELoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

# Train the model
for epoch in range(100):
  # Forward pass
  y_pred = model(x)

  # Compute the loss
  loss = loss_fn(y_pred, y)

  # Backward pass
  optimizer.zero_grad()
  loss.backward()

  # Update the parameters
  optimizer.step()

  # Print the progress
  if epoch % 10 == 0:
    print(f"Epoch: {epoch}, Loss: {loss.item():.4f}")

# Make predictions
y_pred = model(x)

# Plot the results
plt.plot(x.numpy(), y.numpy(), 'ro', label='Original data')
plt.plot(x.numpy(), y_pred.detach().numpy(), 'b', label='Predicted data')
plt.legend()
plt.show()
# Out:
# Epoch: 0, Loss: 0.7078
# Epoch: 10, Loss: 0.5223
# Epoch: 20, Loss: 0.3964
# Epoch: 30, Loss: 0.3106
# Epoch: 40, Loss: 0.2517
# Epoch: 50, Loss: 0.2111
# Epoch: 60, Loss: 0.1828
# Epoch: 70, Loss: 0.1629
# Epoch: 80, Loss: 0.1487
# Epoch: 90, Loss: 0.1385
